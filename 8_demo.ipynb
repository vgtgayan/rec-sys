# %%
import numpy as np
import pandas as pd
import gc
from implicit.datasets.lastfm import get_lastfm
from implicit.nearest_neighbours import bm25_weight, BM25Recommender
from implicit.als import AlternatingLeastSquares
from implicit.cpu.bpr import BayesianPersonalizedRanking
from implicit.recommender_base import RecommenderBase
from implicit import evaluation
from utils import *
import json
import statistics

# %% [markdown]
# ### Set model weights

# %%
BPR_WEIGHT = 0.5
ALS_WEIGHT = 0.8
BM25_WEIGHT = 1
K = 10

# %% [markdown]
# ### Load dataset

# %%
amazon_beauty_df = pd.read_csv("ratings_Beauty.csv")
user_map, item_map, amazon_beauty_csr = pandas_df_to_csr(amazon_beauty_df)

# %%
amazon_beauty_coo_bm25 = bm25_weight(amazon_beauty_csr, K1=100, B=0.8)

# %%
# Test-Train Split
train_csr, test_csr = evaluation.train_test_split(amazon_beauty_coo_bm25, train_percentage=0.8, random_state=55)
print(f"Train size: {train_csr.size} \n Test size: {test_csr.size}")
# Out:
# Train size: 1618938
#  Test size: 404132

# %% [markdown]
# ### Load models

# %%
ALS_model = AlternatingLeastSquares(factors=128, regularization=0.1, alpha=3.0)
ALS_model.fit(train_csr)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [34:06<00:00, 136.43s/it]

# %%
# ALS_model = AlternatingLeastSquares.load("4_CF_ALS_implicit")
BPR_model = BayesianPersonalizedRanking.load("5_CF_BPR_implicit")
BM25_model = BM25Recommender.load("6_BM25")

# %% [markdown]
# ### Inference

# %%
# Dictionary to store intermediate recommendations and ensemble results
results = {}
results["BPR"] = {"weight": BPR_WEIGHT}
results["ALS"] = {"weight": ALS_WEIGHT}
results["BM25"] = {"weight": BM25_WEIGHT}
results["ENSEMBLE"] = {"weight": 1}
results
# Out:
# {'BPR': {'weight': 0.5},
#  'ALS': {'weight': 0.8},
#  'BM25': {'weight': 1},
#  'ENSEMBLE': {'weight': 1}}

# %%
test_coo = test_csr.tocoo()

# %%
actual_dict = {}
for user_id, product_id, rating in zip(test_coo.row, test_coo.col, test_coo.data):
    # print(f"Processing: user_id: {user_id}, product_id: {product_id}, rating: {rating}")
    print(user_id, end = ', ')
    # Retrieve actual products and ratings
    if user_id in actual_dict:
        actual_dict[user_id].append(product_id)
    else:
        actual_dict[user_id] = [product_id]
# Out:
# 1, 6, 11, 12, 13, 16, 19, 24, 32, 35, 38, 39, 42, 47, 49, 53, 58, 59, 59, 67, 71, 73, 73, 75, 80, 90, 97, 109, 110, 116, 118, 118, 120, 121, 126, 128, 131, 142, 154, 163, 166, 168, 171, 172, 176, 183, 186, 187, 189, 189, 189, 195, 198, 201, 202, 205, 209, 211, 218, 220, 222, 226, 226, 227, 231, 239, 240, 242, 246, 247, 249, 251, 256, 258, 259, 264, 266, 274, 289, 297, 298, 304, 312, 316, 318, 320, 321, 328, 337, 338, 338, 338, 340, 346, 350, 351, 351, 351, 354, 357, 357, 361, 363, 365, 370, 372, 374, 374, 377, 380, 382, 392, 397, 398, 413, 416, 417, 417, 418, 423, 424, 425, 426, 426, 426, 426, 438, 446, 453, 458, 464, 470, 472, 475, 477, 487, 499, 500, 500, 501, 514, 517, 522, 530, 530, 530, 530, 530, 539, 543, 554, 557, 566, 569, 570, 573, 577, 579, 588, 589, 591, 597, 598, 602, 603, 604, 607, 608, 610, 611, 620, 624, 624, 625, 626, 629, 633, 635, 636, 647, 647, 648, 653, 655, 655, 656, 657, 658, 660, 664, 664, 673, 673, 673, 673, 673, 674, 679, 686, 688, 694, 696, 696, 697, 711, 717, 719, 720, 721, 726, 727, 728, 732, 732, 733, 735, 735, 737, 740, 741, 742, 742, 744, 745, 747, 748, 751, 752, 758, 758, 759, 760, 762, 763, 765, 770, 772, 774, 777, 779, 790, 797, 800, 801, 803, 806, 813, 823, 823, 824, 833, 836, 840, 843, 844, 845, 846, 850, 850, 851, 852, 856, 856, 861, 862, 866, 870, 873, 874, 876, 881, 886, 892, 893, 905, 905, 910, 913, 916, 917, 925, 931, 931, 933, 935, 935, 937, 937, 938, 939, 941, 948, 951, 965, 968, 972, 972, 974, 978, 979, 980, 984, 990, 990, 998, 1001, 1003, 1006, 1013, 1015, 1021, 1029, 1030, 1033, 1035, 1036, 1037, 1039, 1043, 1044, 1045, 1045, 1049, 1049, 1051, 1054, 1057, 1059, 1061, 1068, 1068, 1073, 1076, 1077, 1084, 1088, 1089, 1093, 1094, 1099, 1104, 1108, 1111, 1113, 1119, 1120, 1121, 1122, 1123, 1126, 1136, 1139, 1141, 1144, 1145, 1150, 1151, 1151, 1151, 1152, 1154, 1156, 1163, 1168, 1170, 1174, 1175, 1178, 1180, 1180, 1182, 1183, 1184, 1186, 1188, 1191, 1193, 1195, 1201, 1205, 1207, 1209, 1214, 1216, 1217, 1227, 1232, 1233, 1235, 1241, 1251, 1260, 1266, 1268, 1277, 1278, 1287, 1298, 1301, 1305, 1311, 1313, 1314, 1315, 1317, 1318, 1319, 1320, 1342, 1344, 1346, 1355, 1359, 1366, 1368, 1371, 1373, 1379, 1381, 1383, 1385, 1385, 1391, 1393, 1397, 1399, 1400, 1408, 1409, 1414, 1418, 1423, 1432, 1436, 1450, 1450, 1456, 1457, 1462, 1462, 1462, 1462, 1462, 1464, 1465, 1465, 1465, 1467, 1468, 1470, 1477, 1478, 1499, 1501, 1501, 1506, 1508, 1510, 1510, 1510, 1513, 1519, 1529, 1534, 1535, 1538, 1540, 1544, 1552, 1557, 1562, 1563, 1565, 1567, 1575, 1577, 1579, 1581, 1591, 1592, 1594, 1597, 1602, 1602, 1604, 1604, 1604, 1604, 1606, 1607, 1610, 1612, 1618, 1619, 1623, 1627, 1632, 1634, 1636, 1640, 1643, 1645, 1649, 1656, 1658, 1661, 1662, 1665, 1668, 1668, 1673, 1673, 1679, 1684, 1686, 1692, 1693, 1698, 1698, 1723, 1724, 1724, 1724, 1726, 1727, 1728, 1751, 1752, 1758, 1759, 1759, 1766, 1768, 1772, 1777, 1779, 1781, 1781, 1781, 1783, 1784, 1786, 1789, 1791, 1797, 1800, 1803, 1806, 1807, 1813, 1814, 1817, 1825, 1826, 1827, 1829, 1836, 1837, 1843, 1844, 1845, 1846, 1847, 1848, 1852, 1854, 1855, 1855, 1858, 1861, 1863, 1864, 1865, 1865, 1866, 1868, 1868, 1868, 1868, 1868, 1868, 1868, 1868, 1868, 1868, 1868, 1868, 1869, 1870, 1886, 1886, 1886, 1888, 1892, 1894, 1895, 1895, 1895, 1900, 1900, 1902, 1903, 1905, 1909, 1913, 1918, 1925, 1926, 1927, 1941, 1944, 1946, 1946, 1946, 1950, 1955, 1956, 1957, 1962, 1966, 1968, 1972, 1976, 1977, 1987, 1989, 1990, 1993, 1994, 1997, 2000, 2001, 2005, 2009, 2011, 2017, 2019, 2025, 2028, 2033, 2036, 2037, 2038, 2041, 2045, 2046, 2050, 2057, 2064, 2065, 2068, 2069, 2069, 2070, 2070, 2071, 2074, 2076, 2077, 2078, 2091, 2095, 2102, 2103, 2103, 2115, 2118, 2129, 2133, 2133, 2134, 2134, 2135, 2138, 2142, 2151, 2151, 2154, 2157, 2158, 2159, 2159, 2161, 2162, 2169, 2180, 2181, 2184, 2186, 2187, 2188, 2190, 2199, 2199, 2201, 2204, 2207, 2210, 2214, 2215, 2220, 2226, 2227, 2229, 2231, 2234, 2241, 2246, 2248, 2249, 2260, 2260, 2260, 2260, 2260, 2261, 2263, 2264, 2268, 2269, 2277, 2278, 22 ...
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["test"]
mycol = mydb["products"]

# %%
image_id_dict = {}
counter = 0
for x in mycol.find():
    image_id = x['_id']
    # print(image_id)
    image_id_dict[image_id] = None
    counter += 1
    if counter == len(item_map):
        break
assert counter == len(image_id_dict.keys())

# %%
prod_img_map = {}
counter = 0
for x in mycol.find():
    image_id = x['_id']
    # print(image_id)
    prod_img_map[counter] = image_id
    counter += 1
    if counter == len(item_map):
        break

# %%
# myclient.close()

# %%
def get_rec(user_id: int):
    # Get recommendation from each model
    ids, scores = BPR_model.recommend(user_id, test_csr[user_id], N=K, filter_already_liked_items=False)
    results["BPR"][user_id] = {"product_ids": list(ids), "scores": list(scores)}
    
    ids, scores = ALS_model.recommend(user_id, test_csr[user_id], N=K, filter_already_liked_items=False)
    results["ALS"][user_id] = {"product_ids": list(ids), "scores": list(scores)}
    
    ids, scores = BM25_model.recommend(user_id, test_csr[user_id], N=K, filter_already_liked_items=False)
    results["BM25"][user_id] = {"product_ids": list(ids), "scores": list(scores)}
    
    # Ensemble results
    ensemble_results = {}
    for _model, _results in results.items():
        if _model == "ENSEMBLE":
            continue
        scores = _results[user_id]['scores']
        # Check if all product scores are equal or empty
        if len(set(scores)) <= 1:
            # print(f"Skipping Model: {_model}, User Id: {user_id}")
            continue
        # Score is normalized to range 0-1 and then weighted by the specified model weight 
        normalized_scores = normalize(arr=scores, t_max=_results['weight'])
        # print("Normalized scores: ", normalized_scores)
        for id, score in zip(_results[user_id]['product_ids'], normalized_scores):
            # Case where product is already recommended by one or more other models
            if id in ensemble_results:
                ensemble_results[id] += score # Add the score to the previous value
                ensemble_results[id] /= 2 # Average the score (This is a rough average)
            # Case where product is recommended first time by current model
            else:
                ensemble_results[id] = score
        
    ensemble_results = sort_by_score(ensemble_results)
    results["ENSEMBLE"][user_id] = {"product_ids": list(ensemble_results.keys()), "scores": list(ensemble_results.values())}
    return results["ENSEMBLE"][user_id]["product_ids"][:K]

# %%
get_rec(user_id=821601)
# Out:
# [96976, 200498, 4542, 2693, 198411, 174709, 21261, 4524, 4545, 120616]

# %% [markdown]
# ### Demo

# %%
import io
import gradio as gr
from skimage.io import imread, imshow

# %%
def get_product_image(product_id: int):
    query = { "_id": product_id }
    for x in mycol.find(query):
        for e, pic in enumerate(x['imgs']):
            picture = imread(io.BytesIO(pic['picture']))
            # do something with the picture, etc
            # imshow(picture)
    return picture

# %%
def grad_wrapper(user_id):
    results = get_rec(user_id=int(user_id))
    img_list = []
    for prod_id in results:
        img_list.append(
            get_product_image(
                product_id=prod_img_map[prod_id]
            )
        )
    return img_list

# %%
demo = gr.Interface(fn=grad_wrapper, inputs="number", outputs=["image", "image", "image", "image", "image", "image", "image", "image", "image", "image"])

demo.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7867
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7867/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
